# %%
import matplotlib.pyplot as plt
from skimage import io, color

image = plt.imread('D:\\pythonProject\\anh_mau.jpg')
red_channel = image[:,:,0]
plt.hist(red_channel.ravel(), bins=256)
plt.title('Red Histogram')
plt.show()
